# %%
# import libraries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cleaning_car.csv')
df
# Out:
#      Unnamed: 0   company                                    name  year  \
# 0             0   Hyundai    Hyundai Santro Xing XO eRLX Euro III  2007
# 1             1   Hyundai  Hyundai Grand i10 Magna 1.2 Kappa VTVT  2014
# 2             2      Ford        Ford EcoSport Titanium 1.5L TDCi  2014
# 3             3      Ford                               Ford Figo  2012
# 4             4   Hyundai                             Hyundai Eon  2013
# ..          ...       ...                                     ...   ...
# 646         646    Maruti              Maruti Suzuki Ritz VXI ABS  2011
# 647         647      Tata               Tata Indica V2 DLE BS III  2009
# 648         648    Toyota                    Toyota Corolla Altis  2009
# 649         649      Tata                     Tata Zest XM Diesel  2018
# 650         650  Mahindra                      Mahindra Quanto C8  2013
#
#      kms_driven fuel_type     Price
# 0         45000    Petrol   80000.0
# 1         28000    Petrol  325000.0
# 2         36000    Diesel  575000.0
# 3         41000    Diesel  175000.0
# 4         25000    Petrol  190000.0
# ..          ...       ...       ...
# 646       50000    Petrol  270000.0
# 647       30000    Diesel  110000.0
# 648      132000    Petrol  300000.0
# 649       27000    Diesel  260000.0
# 650       40000    Diesel  390000.0
#
# [651 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651 entries, 0 to 650
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  651 non-null    int64
#  1   company     651 non-null    object
#  2   name        651 non-null    object
#  3   year        651 non-null    int64
#  4   kms_driven  651 non-null    int64
#  5   fuel_type   651 non-null    object
#  6   Price       651 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 35.7+ KB

# %%
x = df[['company', 'name', 'year', 'kms_driven', 'fuel_type']]
y = df[['Price']]

# %%
x
# Out:
#       company                                    name  year  kms_driven  \
# 0     Hyundai    Hyundai Santro Xing XO eRLX Euro III  2007       45000
# 1     Hyundai  Hyundai Grand i10 Magna 1.2 Kappa VTVT  2014       28000
# 2        Ford        Ford EcoSport Titanium 1.5L TDCi  2014       36000
# 3        Ford                               Ford Figo  2012       41000
# 4     Hyundai                             Hyundai Eon  2013       25000
# ..        ...                                     ...   ...         ...
# 646    Maruti              Maruti Suzuki Ritz VXI ABS  2011       50000
# 647      Tata               Tata Indica V2 DLE BS III  2009       30000
# 648    Toyota                    Toyota Corolla Altis  2009      132000
# 649      Tata                     Tata Zest XM Diesel  2018       27000
# 650  Mahindra                      Mahindra Quanto C8  2013       40000
#
#     fuel_type
# 0      Petrol
# 1      Petrol
# 2      Diesel
# 3      Diesel
# 4      Petrol
# ..        ...
# 646    Petrol
# 647    Diesel
# 648    Petrol
# 649    Diesel
# 650    Diesel
#
# [651 rows x 5 columns]

# %%
x['company'].unique()
# Out:
# array(['Hyundai', 'Ford', 'Maruti', 'Skoda', 'Mahindra', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat',
#        'Mercedes', 'Land', 'Force', 'Jaguar', 'Volvo'], dtype=object)

# %%
x['fuel_type'].unique
# Out:
# <bound method Series.unique of 0      Petrol
# 1      Petrol
# 2      Diesel
# 3      Diesel
# 4      Petrol
#         ...
# 646    Petrol
# 647    Diesel
# 648    Petrol
# 649    Diesel
# 650    Diesel
# Name: fuel_type, Length: 651, dtype: object>

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
ohe = OneHotEncoder()
ohe.fit(x[['company', 'name', 'fuel_type']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#         'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Land', 'Mahindra',
#         'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Renault',
#         'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'], dtype=object),
#  array(['Audi A3 Cabriolet 40 TFSI',
#         'Audi A4 1.8 TFSI Multitronic Premium Plus',
#         'Audi A4 2.0 TDI 177bhp Premium', 'Audi A6 2.0 TDI Premium',
#         'Audi Q3 2.0 TDI quattro Premium',
#         'Audi Q5 2.0 TDI quattro Premium Plus', 'Audi Q7',
#         'BMW 3 Series 320d Sedan', 'BMW 3 Series 320i',
#         'BMW 5 Series 520d Sedan', 'BMW 5 Series 530i',
#         'BMW 7 Series 740Li Sedan', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d xLine', 'Chevrolet Beat',
#         'Chevrolet Beat Diesel', 'Chevrolet Beat LS Diesel',
#         'Chevrolet Beat LS Petrol', 'Chevrolet Beat LT Diesel',
#         'Chevrolet Beat LT Opt Diesel', 'Chevrolet Beat LT Petrol',
#         'Chevrolet Beat PS Diesel', 'Chevrolet Cruze LTZ',
#         'Chevrolet Cruze LTZ AT', 'Chevrolet Enjoy',
#         'Chevrolet Enjoy 1.4 LS 8 STR', 'Chevrolet Sail 1.2 LS',
#         'Chevrolet Sail UVA Petrol LT ABS', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0 LT', 'Chevrolet Spark LS 1.0',
#         'Chevrolet Spark LT 1.0', 'Chevrolet Spark LT 1.0 Airbag',
#         'Chevrolet Tavera LS B3 10 Seats BSII', 'Chevrolet Tavera Neo',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Datsun Redi GO S',
#         'Fiat Linea Emotion 1.4 L T Jet Petrol', 'Fiat Petra ELX 1.2 PS',
#         'Fiat Punto Emotion 1.2', 'Force Motors One SUV', 'Ford EcoSport',
#         'Ford EcoSport Ambiente 1.5L TDCi',
#         'Ford EcoSport Titanium 1.5 TDCi',
#         'Ford EcoSport Titanium 1.5L TDCi',
#         'Ford EcoSport Trend 1.5 Ti VCT', 'Ford EcoSport Trend 1.5L TDCi',
#         'Ford EcoSport Trend 1.5L Ti VCT', 'Ford Fiesta',
#         'Ford Fiesta SXi 1.6 ABS', 'Ford Figo', 'Ford Figo Diesel EXI',
#         'Ford Figo Diesel EXI Option',
#         'Ford Figo Duratorq Diesel Titanium 1.4', 'Ford Figo Petrol LXI',
#         'Ford Fusion 1.4 TDCi Diesel', 'Ford Ikon 1.3 CLXi NXt Finesse',
#         'Ford Ikon 1.3 Flair Josh 100', 'Ford Ikon 1.6 Nxt',
#         'Hindustan Motors Ambassador',
#         'Hindustan Motors Ambassador Classic Mark 4 – Befo',
#         'Honda Accord', 'Honda Amaze', 'Honda Amaze 1.2 S i VTEC',
#         'Honda Amaze 1.5 E i DTEC', 'Honda Amaze 1.5 S i DTEC',
#         'Honda Amaze 1.5 SX i DTEC', 'Honda Brio', 'Honda Brio V MT',
#         'Honda Brio VX AT', 'Honda City', 'Honda City 1.5 E MT',
#         'Honda City 1.5 EXi New', 'Honda City 1.5 S Inspire',
#         'Honda City 1.5 S MT', 'Honda City 1.5 V AT',
#         'Honda City 1.5 V MT', 'Honda City SV',
#         'Honda City VX O MT Diesel', 'Honda City VX Petrol',
#         'Honda City ZX CVT', 'Honda City ZX EXi', 'Honda City ZX GXi',
#         'Honda City ZX VTEC', 'Honda Jazz S MT', 'Honda Jazz VX MT',
#         'Honda Mobilio', 'Honda Mobilio S i DTEC',
#         'Honda WR V S MT Petrol', 'Hyundai Accent',
#         'Hyundai Accent Executive Edition', 'Hyundai Accent GLE',
#         'Hyundai Accent GLX', 'Hyundai Creta',
#         'Hyundai Creta 1.6 SX Plus Petrol', 'Hyundai Elantra 1.8 S',
#         'Hyundai Elantra SX', 'Hyundai Elite i20',
#         'Hyundai Elite i20 Asta 1.2', 'Hyundai Elite i20 Asta 1.4 CRDI',
#         'Hyundai Elite i20 Magna 1.2', 'Hyundai Elite i20 Sportz 1.2',
#         'Hyundai Eon', 'Hyundai Eon D Lite Plus', 'Hyundai Eon Era Plus',
#         'Hyundai Eon Magna Plus', 'Hyundai Eon Sportz',
#         'Hyundai Fluidic Verna 1.6 CRDi SX', 'Hyundai Getz',
#         'Hyundai Getz GLE', 'Hyundai Getz Prime 1.3 GLX',
#         'Hyundai Getz Prime 1.3 GVS', 'Hyundai Grand i10 Asta 1.1 CRDi',
#         'Hyundai Grand i10 Asta 1.2 Kappa VTVT',
#         'Hyundai Grand i10 Asta 1.2 Kappa VTVT O',
#         'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#         'Hyundai Grand i10 Magna AT 1.2 Kappa VTVT',
#         'Hyundai Grand i10 Sportz 1.2 Kappa VTVT',
#         'Hyundai Grand i10 Sportz O 1.2 Kappa VTVT', 'Hyundai Santro',
#         'Hyundai Santro AE GLS Audio', 'Hyundai Santro Xing',
#         'Hyundai Santro Xing GL', 'Hyundai Santro Xing GLS',
#         'Hyundai Santro Xing XL AT eRLX Euro III',
#         'Hyundai Santro Xing XL eRLX Euro III',
#         'Hyundai Santro Xing XO eRLX Euro III',
#         'Hyundai Sonata Transform 2.4 GDi MT', 'Hyundai Verna',
#         'Hyundai Verna 1.4 VTVT', 'Hyundai Verna 1.6 CRDI E',
#         'Hyundai Verna 1.6 CRDI SX', 'Hyundai Verna 1.6 CRDI SX Plus AT',
#         'Hyundai Verna 1.6 EX VTVT', 'Hyundai Verna Fluidic',
#         'Hyundai Verna Fluidic 1.6 VTVT SX', 'Hyundai Verna Fluidic New',
#         'Hyundai Verna Transform SX VTVT', 'Hyundai Verna VGT CRDi SX ABS',
#         'Hyundai Xcent Base 1.1 CRDi', 'Hyundai Xcent SX 1.2',
#         'Hyundai i10', 'Hyundai i10 Era', 'Hyundai i10 Magna 1.2',
#         'Hyundai i10 Magna 1.2 Kappa2', 'Hyundai i10 Sportz',
#         'Hyundai i10 Sportz 1.2', 'Hyundai i20', 'Hyundai i20 Active',
#         'Hyundai i20 Active 1.2 SX', 'Hyundai i20 Active 1.4L SX O',
#         'Hyundai i20 Asta', 'Hyundai i20 Asta 1.2',
#         'Hyundai i20 Asta 1.4 CRDI 6 Speed', 'Hyundai i20 Magna',
#         'Hyundai i20 Magna 1.2', 'Hyundai i20 Magna O 1.2',
#         'Hyundai i20 Select Variant', 'Hyundai i20 Sportz 1.2',
#         'Hyundai i20 Sportz 1.4 CRDI', 'Jaguar XF 2.2 Diesel Luxury',
#         'Land Rover Freelander 2 SE', 'Mahindra Bolero DI',
#         'Mahindra Bolero DI BSII', 'Mahindra Bolero SLE BS IV',
#         'Mahindra KUV100', 'Mahindra KUV100 K8 D 6 STR', 'Mahindra Logan',
#         'Mahindra Logan Diesel 1.5 DLS', 'Mahindra Quanto C4',
#         'Mahindra Quanto C8', 'Mahindra Scorpio',
#         'Mahindra Scorpio 2.6 CRDe', 'Mahindra Scorpio 2.6 SLX',
#         'Mahindra Scorpio LX BS III', 'Mahindra Scorpio S10',
#         'Mahindra Scorpio S10 4WD', 'Mahindra Scorpio S4',
#         'Mahindra Scorpio SLE BS IV', 'Mahindra Scorpio SLX',
#         'Mahindra Scorpio SLX 2.6 Turbo 8 Str',
#         'Mahindra Scorpio VLX 2.2 mHawk Airbag BSIV',
#         'Mahindra Scorpio VLX 2WD BS IV',
#         'Mahindra Scorpio VLX 4WD Airbag', 'Mahindra Scorpio VLX Airbag',
#         'Mahindra Scorpio VLX Special Edition BS III',
#         'Mahindra Scorpio Vlx BSIV',
#         'Mahindra Scorpio W Turbo 2.6DX 9 Seater',
#         'Mahindra TUV300 T4 Plus', 'Mahindra Thar CRDe 4x4 AC',
#         'Mahindra XUV500', 'Mahindra XUV500 W10', 'Mahindra XUV500 W6',
#         'Mahindra XUV500 W8', 'Mahindra XUV500 W8 AWD 2013',
#         'Mahindra Xylo D2', 'Mahindra Xylo D2 BS IV', 'Mahindra Xylo E4',
#         'Mahindra Xylo E8', 'Mahindra Xylo E8 BS IV', 'Maruti Suzuki 800',
#         'Maruti Suzuki 800 Std BS III', 'Maruti Suzuki A Star Lxi',
#         'Maruti Suzuki Alto', 'Maruti Suzuki Alto 800',
#         'Maruti Suzuki Alto 800 LXI CNG O', 'Maruti Suzuki Alto 800 Lx',
#         'Maruti Suzuki Alto 800 Lxi', 'Maruti Suzuki Alto 800 Vxi',
#         'Maruti Suzuki Alto K10 LXi CNG', 'Maruti Suzuki Alto K10 VXi',
#         'Maruti Suzuki Alto K10 VXi AMT', 'Maruti Suzuki Alto K10 VXi AT',
#         'Maruti Suzuki Alto LX', 'Maruti Suzuki Alto LXi BS III',
#         'Maruti Suzuki Alto Std BS IV', 'Maruti Suzuki Baleno Delta 1.2',
#         'Maruti Suzuki Baleno Sigma 1.2', 'Maruti Suzuki Celerio VDi',
#         'Maruti Suzuki Ciaz ZXI Plus', 'Maruti Suzuki Ciaz ZXi Plus RS',
#         'Maruti Suzuki Dzire', 'Maruti Suzuki Dzire LDI',
#         'Maruti Suzuki Dzire VDI', 'Maruti Suzuki Dzire ZXI',
#         'Maruti Suzuki Eeco 5 STR WITH AC HTR', 'Maruti Suzuki Eeco 7 STR',
#         'Maruti Suzuki Ertiga', 'Maruti Suzuki Ertiga LDi',
#         'Maruti Suzuki Ertiga VDi', 'Maruti Suzuki Ertiga Vxi',
#         'Maruti Suzuki Ertiga ZXI Plus', 'Maruti Suzuki Ertiga ZXi',
#         'Maruti Suzuki Esteem LXi BS III',
#         'Maruti Suzuki Esteem VXi BS III', 'Maruti Suzuki Estilo LX BS IV',
#         'Maruti Suzuki Estilo VXi ABS BS IV',
#         'Maruti Suzuki Maruti 800 AC', 'Maruti Suzuki Maruti 800 Std',
#         'Maruti Suzuki Maruti 800 Std – Befo', 'Maruti Suzuki Omni',
#         'Maruti Suzuki Omni 8 STR BS III',
#         'Maruti Suzuki Omni E 8 STR BS IV', 'Maruti Suzuki Omni LPG BS IV',
#         'Maruti Suzuki Omni Limited Edition', 'Maruti Suzuki Ritz',
#         'Maruti Suzuki Ritz GENUS VXI', 'Maruti Suzuki Ritz LDi',
#         'Maruti Suzuki Ritz VDi', 'Maruti Suzuki Ritz VXI',
#         'Maruti Suzuki Ritz VXI ABS', 'Maruti Suzuki S Cross Sigma 1.3',
#         'Maruti Suzuki SX4', 'Maruti Suzuki SX4 Celebration Diesel',
#         'Maruti Suzuki SX4 ZXI MT', 'Maruti Suzuki Stingray VXi',
#         'Maruti Suzuki Swift', 'Maruti Suzuki Swift Dzire',
#         'Maruti Suzuki Swift Dzire Tour LDi',
#         'Maruti Suzuki Swift Dzire Tour LXi',
#         'Maruti Suzuki Swift Dzire Tour VDi',
#         'Maruti Suzuki Swift Dzire VDi',
#         'Maruti Suzuki Swift Dzire VXi 1.2 BS IV',
#         'Maruti Suzuki Swift Dzire ZDi', 'Maruti Suzuki Swift GLAM',
#         'Maruti Suzuki Swift LDi', 'Maruti Suzuki Swift RS VDI',
#         'Maruti Suzuki Swift Select Variant', 'Maruti Suzuki Swift VDi',
#         'Maruti Suzuki Swift VDi ABS', 'Maruti Suzuki Swift VDi BS IV',
#         'Maruti Suzuki Swift VXI BSIII',
#         'Maruti Suzuki Swift VXi 1.2 ABS BS IV',
#         'Maruti Suzuki Swift VXi 1.2 BS IV',
#         'Maruti Suzuki Swift Vdi BSIII',
#         'Maruti Suzuki Swift ZXi 1.2 BS IV',
#         'Maruti Suzuki Versa DX2 8 SEATER BSIII',
#         'Maruti Suzuki Vitara Brezza', 'Maruti Suzuki Vitara Brezza LDi O',
#         'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Wagon R',
#         'Maruti Suzuki Wagon R 1.0', 'Maruti Suzuki Wagon R 1.0 VXi',
#         'Maruti Suzuki Wagon R AX BSIV', 'Maruti Suzuki Wagon R Duo Lxi',
#         'Maruti Suzuki Wagon R LX BS III',
#         'Maruti Suzuki Wagon R LX BS IV',
#         'Maruti Suzuki Wagon R LXI BS IV',
#         'Maruti Suzuki Wagon R LXi BS III',
#         'Maruti Suzuki Wagon R Select Variant',
#         'Maruti Suzuki Wagon R VXI BS IV',
#         'Maruti Suzuki Wagon R VXi BS III',
#         'Maruti Suzuki Wagon R VXi Minor', 'Maruti Suzuki Zen Estilo',
#         'Maruti Suzuki Zen Estilo LXI Green CNG',
#         'Maruti Suzuki Zen LX BSII', 'Maruti Suzuki Zen LXi BS III',
#         'Maruti Suzuki Zen LXi BSII', 'Maruti Suzuki Zen VX',
#         'Mercedes Benz A Class A 180 Sport Petrol',
#         'Mercedes Benz B Class B180 Sports',
#         'Mercedes Benz C Class 200 CDI Classic',
#         'Mercedes Benz C Class 200 K MT',
#         'Mercedes Benz C Class C 220 CDI Avantgarde',
#         'Mercedes Benz GLA Class 200 CDI Sport', 'Mini Cooper S',
#         'Mini Cooper S 1.6', 'Mitsubishi Lancer 1.8 LXi',
#         'Mitsubishi Pajero Sport 2.5 AT',
#         'Mitsubishi Pajero Sport Limited Edition', 'Nissan Micra XL',
#         'Nissan Micra XV', 'Nissan Sunny', 'Nissan Sunny XL',
#         'Nissan Terrano XL D Plus', 'Renault Duster',
#         'Renault Duster 110 PS RxL Diesel',
#         'Renault Duster 110 PS RxZ Diesel',
#         'Renault Duster 110 PS RxZ Diesel Plus',
#         'Renault Duster 110PS Diesel RxZ',
#         'Renault Duster 85 PS RxE Diesel',
#         'Renault Duster 85 PS RxL Diesel',
#         'Renault Duster 85 PS RxL Explore LE',
#         'Renault Duster 85PS Diesel RxL Optional with Nav',
#         'Renault Duster RxL Petrol', 'Renault Kwid',
#         'Renault Kwid 1.0 RXT AMT', 'Renault Kwid RXT',
#         'Renault Kwid RXT Opt', 'Renault Lodgy 85 PS RXL',
#         'Renault Scala RxL Diesel', 'Renault Scala RxL Diesel Travelogue',
#         'Skoda Fabia', 'Skoda Fabia 1.2L Diesel Ambiente',
#         'Skoda Fabia 1.2L Diesel Elegance', 'Skoda Fabia Classic 1.2 MPI',
#         'Skoda Laura', 'Skoda Octavia Classic 1.9 TDI MT',
#         'Skoda Rapid Elegance 1.6 TDI CR MT', 'Skoda Superb 1.8 TFSI AT',
#         'Skoda Yeti Ambition 2.0 TDI CR 4x2', 'Tata Aria Pleasure 4X2',
#         'Tata Bolt XM Petrol', 'Tata Indica', 'Tata Indica V2',
#         'Tata Indica V2 DLE BS III', 'Tata Indica V2 DLG',
#         'Tata Indica V2 DLS BS III', 'Tata Indica V2 DLX BS III',
#         'Tata Indica V2 LS', 'Tata Indica V2 Xeta e GLE',
#         'Tata Indica V2 eLS', 'Tata Indica eV2 LS',
#         'Tata Indica eV2 eXeta eGLX', 'Tata Indigo CS',
#         'Tata Indigo CS GLS', 'Tata Indigo CS LS DiCOR',
#         'Tata Indigo CS eLS BS IV', 'Tata Indigo CS eLX BS IV',
#         'Tata Indigo LS', 'Tata Indigo LX TDI BS III',
#         'Tata Indigo Marina LS', 'Tata Indigo eCS',
#         'Tata Indigo eCS LS CR4 BS IV', 'Tata Indigo eCS LX CR4 BS IV',
#         'Tata Indigo eCS LX TDI BS III', 'Tata Indigo eCS VX CR4 BS IV',
#         'Tata Manza', 'Tata Manza Aqua Quadrajet',
#         'Tata Manza Aura Quadrajet', 'Tata Manza ELAN Quadrajet',
#         'Tata Nano GenX XMA', 'Tata Nano LX Special Edition',
#         'Tata Sumo Gold EX BS IV', 'Tata Sumo Gold FX BSIII',
#         'Tata Sumo Gold LX BS IV', 'Tata Sumo Gold Select Variant',
#         'Tata Sumo Grande MKII GX', 'Tata Sumo Victa EX 10 by 7 Str BSIII',
#         'Tata Tiago Revotron XZ', 'Tata Venture EX 8 STR',
#         'Tata Vista Quadrajet VX', 'Tata Zest Quadrajet 1.3',
#         'Tata Zest XE 75 PS Diesel', 'Tata Zest XM Diesel',
#         'Toyota Corolla', 'Toyota Corolla Altis',
#         'Toyota Corolla Altis 1.8 GL', 'Toyota Corolla Altis 1.8 J',
#         'Toyota Corolla Altis Diesel D4DG',
#         'Toyota Corolla Altis GL Petrol',
#         'Toyota Corolla Altis Petrol Ltd',
#         'Toyota Corolla Altis VL AT Petrol', 'Toyota Corolla H2',
#         'Toyota Etios', 'Toyota Etios G', 'Toyota Etios GD',
#         'Toyota Etios Liva', 'Toyota Etios Liva Diesel',
#         'Toyota Etios Liva G', 'Toyota Etios Liva GD', 'Toyota Fortuner',
#         'Toyota Fortuner 3.0 4x2 MT', 'Toyota Fortuner 3.0 4x4 MT',
#         'Toyota Innova 2.0 G 8 STR BS IV', 'Toyota Innova 2.0 G4',
#         'Toyota Innova 2.5 E 8 STR', 'Toyota Innova 2.5 G BS III 8 STR',
#         'Toyota Innova 2.5 GX BS IV 7 STR', 'Toyota Innova 2.5 V 7 STR',
#         'Toyota Innova 2.5 Z Diesel 7 Seater', 'Toyota Qualis',
#         'Volkswagen Jetta Comfortline 1.9 TDI AT',
#         'Volkswagen Jetta Highline TDI AT',
#         'Volkswagen Passat Diesel Comfortline AT', 'Volkswagen Polo',
#         'Volkswagen Polo Highline Exquisite P',
#         'Volkswagen Polo Highline1.2L P',
#         'Volkswagen Polo Trendline 1.5L D',
#         'Volkswagen Vento Comfortline Diesel',
#         'Volkswagen Vento Comfortline Petrol',
#         'Volkswagen Vento Highline Plus 1.5 Diesel AT',
#         'Volkswagen Vento Konekt Diesel Highline', 'Volvo S80 Summum D4'],
#        dtype=object),
#  array(['Diesel', 'LPG', 'Petrol'], dtype=object)]

# %%
ct = make_column_transformer((OneHotEncoder(categories = ohe.categories_),['company', 'name', 'fuel_type']),remainder = 'passthrough',force_int_remainder_cols=False)
ct
# Out:
# ColumnTransformer(force_int_remainder_cols=False, remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Land', 'Mahindra',
#        'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Renault',
#        'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Vol...
#        'Volkswagen Polo Highline Exquisite P',
#        'Volkswagen Polo Highline1.2L P',
#        'Volkswagen Polo Trendline 1.5L D',
#        'Volkswagen Vento Comfortline Diesel',
#        'Volkswagen Vento Comfortline Petrol',
#        'Volkswagen Vento Highline Plus 1.5 Diesel AT',
#        'Volkswagen Vento Konekt Diesel Highline', 'Volvo S80 Summum D4'],
#       dtype=object),
#                                                            array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                  ['company', 'name', 'fuel_type'])])

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
from sklearn.pipeline import make_pipeline
pipe = make_pipeline(ct, reg)
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Land', 'Mahindra',
#        'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Renault',
#        'Sko...
#        'Volkswagen Polo Highline1.2L P',
#        'Volkswagen Polo Trendline 1.5L D',
#        'Volkswagen Vento Comfortline Diesel',
#        'Volkswagen Vento Comfortline Petrol',
#        'Volkswagen Vento Highline Plus 1.5 Diesel AT',
#        'Volkswagen Vento Konekt Diesel Highline', 'Volvo S80 Summum D4'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.05, random_state = 0)

# %%
x_train
# Out:
#         company                                   name  year  kms_driven  \
# 439        Tata              Tata Zest XE 75 PS Diesel  2017       70000
# 235  Volkswagen                        Volkswagen Polo  2010       60000
# 579     Hyundai  Hyundai Grand i10 Asta 1.2 Kappa VTVT  2014       41000
# 516  Volkswagen    Volkswagen Vento Comfortline Diesel  2011       95000
# 75      Hyundai              Hyundai Verna Fluidic New  2015       35000
# ..          ...                                    ...   ...         ...
# 9       Hyundai            Hyundai Elite i20 Magna 1.2  2014       32000
# 359   Hindustan            Hindustan Motors Ambassador  2002       25000
# 192      Nissan               Nissan Terrano XL D Plus  2015       60000
# 629      Toyota                          Toyota Qualis  2003      100000
# 559      Maruti               Maruti Suzuki Ertiga VDi  2012       48000
#
#     fuel_type
# 439    Diesel
# 235    Diesel
# 579    Petrol
# 516    Diesel
# 75     Diesel
# ..        ...
# 9      Petrol
# 359    Diesel
# 192    Diesel
# 629    Diesel
# 559    Diesel
#
# [618 rows x 5 columns]

# %%
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Land', 'Mahindra',
#        'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Renault',
#        'Sko...
#        'Volkswagen Polo Highline1.2L P',
#        'Volkswagen Polo Trendline 1.5L D',
#        'Volkswagen Vento Comfortline Diesel',
#        'Volkswagen Vento Comfortline Petrol',
#        'Volkswagen Vento Highline Plus 1.5 Diesel AT',
#        'Volkswagen Vento Konekt Diesel Highline', 'Volvo S80 Summum D4'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
result = pipe.predict(x_test)
result
# Out:
# array([[1662684.89779396],
#        [ 229422.74775377],
#        [ 518538.4516319 ],
#        [ 326909.60429319],
#        [ 386063.77159993],
#        [ 279605.98487025],
#        [ 474377.171584  ],
#        [ 278462.14755733],
#        [ 358004.91188016],
#        [ 469848.53960527],
#        [ 150968.15029544],
#        [ 185330.33591492],
#        [ 519692.13061532],
#        [1978999.9128553 ],
#        [ 279970.21553136],
#        [ 174669.8241768 ],
#        [ 233096.25528889],
#        [1293603.69308358],
#        [ 134043.11573505],
#        [ 430109.44142743],
#        [ 128462.98671694],
#        [ 346526.62880187],
#        [ 455834.79306632],
#        [ 298996.09228435],
#        [ 455672.30298814],
#        [ 303265.38885248],
#        [-277402.75587057],
#        [ 187492.92482126],
#        [ 278003.5380036 ],
#        [ 276121.1133539 ],
#        [1571373.95709582],
#        [ 469767.22454412],
#        [ 504500.59758709]])

# %%
y_test
# Out:
#          Price
# 533  3100000.0
# 375   250000.0
# 306   550000.0
# 627   100000.0
# 481   465000.0
# 471   179000.0
# 303   495000.0
# 240   600000.0
# 535   285000.0
# 85    195000.0
# 478   188000.0
# 384   110000.0
# 165   275000.0
# 239  1350000.0
# 337   290000.0
# 249    99999.0
# 122   159500.0
# 395  1150000.0
# 157   135000.0
# 532   970000.0
# 64     90000.0
# 251   324999.0
# 343   730000.0
# 392   380000.0
# 355   225000.0
# 605   425000.0
# 268    30000.0
# 595   400000.0
# 271   225000.0
# 648   300000.0
# 50   1891111.0
# 500   650000.0
# 449   855000.0

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, result)
score
# Out:
# 0.6978620353940552

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
scores = []
for i in range(0,101):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.05, random_state = i)
    pipe.fit(x_train, y_train)
    result = pipe.predict(x_test)
    score = r2_score(y_test, result)
    scores.append(score)

# %%
np.argmax(scores)
# Out:
# 86

# %%
bestindex = np.argmax(scores)

# %%
scores[bestindex]
# Out:
# 0.9008433640757677

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.05, random_state = i)
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Land', 'Mahindra',
#        'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Renault',
#        'Sko...
#        'Volkswagen Polo Highline1.2L P',
#        'Volkswagen Polo Trendline 1.5L D',
#        'Volkswagen Vento Comfortline Diesel',
#        'Volkswagen Vento Comfortline Petrol',
#        'Volkswagen Vento Highline Plus 1.5 Diesel AT',
#        'Volkswagen Vento Konekt Diesel Highline', 'Volvo S80 Summum D4'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
company = input("Enter a Company Name:-")
name = input("Enter a Car Name:-")
year = int(input("Enter a Year:-"))
kms_driven = int(input("Enter a Kms_Driven:-"))
fuel_type = input("Enter a Fuel_Type:-")
columns = ['company', 'name', 'year', 'kms_driven', 'fuel_type']
myinput = pd.DataFrame(columns = columns, data = [[company, name, year, kms_driven, fuel_type]])
myinput
# Out:
# Enter a Company Name:- Hyundai
# Enter a Car Name:- Hyundai Eon
# Enter a Year:- 2020
# Enter a Kms_Driven:- 35000
# Enter a Fuel_Type:- Petrol
#    company         name  year  kms_driven fuel_type
# 0  Hyundai  Hyundai Eon  2020       35000    Petrol

# %%
result = pipe.predict(myinput)
print("You Should buy it for price :-",round(result[0,0]))
# Out:
# You Should buy it for price :- 386791

# %%
import pickle as pkl
pkl.dump(pipe, open('CarProject.pkl','wb'))
