# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cleaning_car.csv')
df
# Out:
#      Unnamed: 0   company                                    name  year  \
# 0             0   Hyundai    Hyundai Santro Xing XO eRLX Euro III  2007
# 1             1   Hyundai  Hyundai Grand i10 Magna 1.2 Kappa VTVT  2014
# 2             2      Ford        Ford EcoSport Titanium 1.5L TDCi  2014
# 3             3      Ford                               Ford Figo  2012
# 4             4   Hyundai                             Hyundai Eon  2013
# ..          ...       ...                                     ...   ...
# 646         646    Maruti              Maruti Suzuki Ritz VXI ABS  2011
# 647         647      Tata               Tata Indica V2 DLE BS III  2009
# 648         648    Toyota                    Toyota Corolla Altis  2009
# 649         649      Tata                     Tata Zest XM Diesel  2018
# 650         650  Mahindra                      Mahindra Quanto C8  2013
#
#      kms_driven fuel_type     Price
# 0         45000    Petrol   80000.0
# ...

# %%
#1. Bar Chart
companywisecount=df.groupby('company')['company'].count()
plt.figure(figsize=(13,5))
a = companywisecount.plot(kind='bar',color='skyblue',title='Company-wise Count')
plt.xticks(rotation=45)
for i,v in enumerate(companywisecount):
    a.text(i,v + 0.1, str(v), ha='center', va='bottom') 
plt.xlabel('Company')
plt.ylabel('Count')
plt.show()

# %%
# 2. Histogram: Distribution of car prices
plt.figure()
sns.histplot(data['Price'], bins=20, kde=True, color='green')
plt.title('Distribution of Car Prices', fontsize=16)
plt.xlabel('Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
# 3. Scatter Plot: Relationship between Kilometers Driven and Price
plt.figure()
plt.scatter(df['kms_driven'], df['Price'], color='green', alpha=0.7)
plt.title('Kilometers Driven vs Price', fontsize=16)
plt.xlabel('Kilometers Driven', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.show()

# %%
# 4. Box Plot: Price distribution by Fuel Type
plt.figure()
sns.boxplot(x='fuel_type', y='Price', data=df, palette='pastel')
plt.title('Price Distribution by Fuel Type', fontsize=16)
plt.xlabel('Fuel Type', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19764\487834201.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='fuel_type', y='Price', data=df, palette='pastel')

# %%
# 5. Line Plot: Price trend over Years
plt.figure()
sns.lineplot(x='year', y='Price', data=df, marker='o', color='blue')
plt.title('Price Trend Over Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.show()

# %%
# 6. Swarm Plot: Price distribution by Company
plt.figure(figsize=(15,5))
sns.swarmplot(x='company', y='Price', data=df, palette='muted')
plt.title('Price Distribution by Company', fontsize=16)
plt.xlabel('Company', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19764\1083305781.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='company', y='Price', data=df, palette='muted')
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 78.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 83.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
